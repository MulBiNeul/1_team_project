# %%
import pandas as pd
from IPython.display import HTML
from autogluon.tabular import TabularPredictor
from sklearn.model_selection import train_test_split

# %%
df_type = pd.read_csv('../../data/preprocessed_data/시도_시군구별_보행자_사고_사고유형_전처리ver.csv')
# df_type
HTML(df_type.head(5).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>연도</th>
#       <th>시군구</th>
#       <th>법정동코드</th>
#       <th>사고내용</th>
#       <th>사망자수</th>
#       <th>중상자수</th>
#       <th>경상자수</th>
#       <th>부상신고자수</th>
#       <th>사고유형</th>
#       <th>도로형태</th>
#       <th>피해자 상해정도</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020</td>
#       <td>서울특별시 종로구 창성동</td>
#       <td>1111010500</td>
#       <td>중상사고</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>차대사람 - 차도통행중</td>
#       <td>교차로 - 교차로부근</td>
#       <td>중상</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020</td>
#       <td>서울특별시 종로구 창성동</td>
#       <td>1111010500</td>
#       <td>중상사고</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>차대사람 - 차도통행중</td>
#       <td>교차로 - 교차로안</td>
#       <td>중상</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020</td>
#       <td>서울특별시 종로구 통인동</td>
#       <td>1111010800</td>
#       <td>경상사고</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>차대사람 - 기타</td>
#       <td>단일로 - 기타</td>
#       <td>경상</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020</td>
#       <td>서울특별시 종로구 누상동</td>
#       <td>1111010900</td>
#       <td>경상사고</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>차대사람 - 차도통행중</td>
#       <td>교차로 - 교차로안</td>
#       <td>경상</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020</td>
#       <td>서울특별시 종로구 누상동</td>
#       <td>1111010900</td>
#       <td>경상사고</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>차대사람 - 기타</td>
#       <td>단일로 - 기타</td>
#       <td>경상</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_type = pd.read_csv('../../data/preprocessed_data/시도_시군구별_보행자_사고_사고유형_전처리ver.csv')
# df_type
HTML(df_type.head(5).to_html())

# 피해 가중 점수 계산
df_risk = df_type.copy()
df_risk['피해가중점수'] = (
    df_risk['사망자수'] * 1 +
    df_risk['중상자수'] * 0.1 +
    df_risk['경상자수'] * 0.01 +
    df_risk['부상신고자수'] * 0.001
)

avg_by_area = df_risk.groupby('시군구')['피해가중점수'].mean().to_dict()        # 시군구별 평균 사고건수 feature 생성
type_weight = df_risk.groupby('사고유형')['피해가중점수'].mean()                 # 사고형태_가중치 = 사고유형별_누적_피해점수 / 전체_평균_피해점수
road_weight = df_risk.groupby('도로형태')['피해가중점수'].mean()                 # 도로형태_가중치 = 도로형태별_누적_피해점수 / 전체_평균_피해점수

df_risk['사고도로조합'] = df_risk['사고유형'] + '_' + df_risk['도로형태']                                        # 사고유형 + 도로형태 조합 변수 생성
df_risk['시군구_평균사고'] = df_risk['시군구'].map(avg_by_area)
df_risk['사고유형가중치'] = df_risk['사고유형'].map(type_weight)
df_risk['도로형태가중치'] = df_risk['도로형태'].map(road_weight)
df_risk['최종위험점수'] = df_risk['피해가중점수'] + 0.5 * (df_risk['사고유형가중치'] + df_risk['도로형태가중치'])       # 최종 위험 점수 계산 (기본 피해 점수 + 유형/도로 가중치 평균)

df_risk['위험도'] = pd.qcut(df_risk['최종위험점수'], q=5, labels=[1, 2, 3, 4, 5])                             # 위험도 5등급 (1=매우 안전 ~ 5=매우 위험)
df_risk['위험도'] = df_risk['위험도'].astype(str)

HTML(df_risk.head(5).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>연도</th>
#       <th>시군구</th>
#       <th>법정동코드</th>
#       <th>사고내용</th>
#       <th>사망자수</th>
#       <th>중상자수</th>
#       <th>경상자수</th>
#       <th>부상신고자수</th>
#       <th>사고유형</th>
#       <th>도로형태</th>
#       <th>피해자 상해정도</th>
#       <th>피해가중점수</th>
#       <th>사고도로조합</th>
#       <th>시군구_평균사고</th>
#       <th>사고유형가중치</th>
#       <th>도로형태가중치</th>
#       <th>최종위험점수</th>
#       <th>위험도</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020</td>
#       <td>서울특별시 종로구 창성동</td>
#       <td>1111010500</td>
#       <td>중상사고</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>차대사람 - 차도통행중</td>
#       <td>교차로 - 교차로부근</td>
#       <td>중상</td>
#       <td>0.10</td>
#       <td>차대사람 - 차도통행중_교차로 - 교차로부근</td>
#       <td>0.10</td>
#       <td>0.131882</td>
#       <td>0.111938</td>
#       <td>0.221910</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020</td>
#       <td>서울특별시 종로구 창성동</td>
#       <td>1111010500</td>
#       <td>중상사고</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>차대사람 - 차도통행중</td>
#       <td>교차로 - 교차로안</td>
#       <td>중상</td>
#       <td>0.10</td>
#       <td>차대사람 - 차도통행중_교차로 - 교차로안</td>
#       <td>0.10</td>
#       <td>0.131882</td>
#       <td>0.117951</td>
#       <td>0.224917</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020</td>
#       <td>서울특별시 종로구 통인동</td>
#       <td>1111010800</td>
#       <td>경상사고</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>차대사람 - 기타</td>
#       <td>단일로 - 기타</td>
#       <td>경상</td>
#       <td>0.01</td>
#       <td>차대사람 - 기타_단일로 - 기타</td>
#       <td>0.01</td>
#       <td>0.092425</td>
#       <td>0.121204</td>
#       <td>0.116814</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020</td>
#       <td>서울특별시 종로구 누상동</td>
#       <td>1111010900</td>
#       <td>경상사고</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>차대사람 - 차도통행중</td>
#       <td>교차로 - 교차로안</td>
#       <td>경상</td>
#       <td>0.01</td>
#       <td>차대사람 - 차도통행중_교차로 - 교차로안</td>
#       <td>0.01</td>
#       <td>0.131882</td>
#       <td>0.117951</td>
#       <td>0.134917</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020</td>
#       <td>서울특별시 종로구 누상동</td>
#       <td>1111010900</td>
#       <td>경상사고</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>차대사람 - 기타</td>
#       <td>단일로 - 기타</td>
#       <td>경상</td>
#       <td>0.01</td>
#       <td>차대사람 - 기타_단일로 - 기타</td>
#       <td>0.01</td>
#       <td>0.092425</td>
#       <td>0.121204</td>
#       <td>0.116814</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# feature 선택
feature_cols = ['시군구', '사고유형', '도로형태', '시군구_평균사고', '사고도로조합']
target_col = '위험도'

df_model = df_risk[feature_cols + [target_col]].dropna()

train_data, test_data = train_test_split(df_risk[feature_cols + [target_col]], test_size=0.2, random_state=42, stratify=df_risk[target_col])

# 모델 학습 (AutoGluon)
predictor = TabularPredictor(label=target_col, path="HighRiskRank/", problem_type='multiclass').fit(
    train_data=train_data,
    presets='high_quality',
    num_cpus=10,
    time_limit=900,
    verbosity=2
)

predictor.save()

# 성능 평가
predictor.evaluate(test_data)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.3.1
# Python Version:     3.11.11
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 24.4.0: Fri Apr 11 18:33:39 PDT 2025; root:xnu-11417.101.15~117/RELEASE_ARM64_T6020
# CPU Count:          12
# Memory Avail:       2.60 GB / 16.00 GB (16.3%)
# Disk Space Avail:   15.43 GB / 460.43 GB (3.4%)
# ===================================================
# Presets specified: ['high_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 225s of the 900s of remaining time (25%).
# 		Context path: "/Users/leehyunseung/Library/Mobile Documents/.Trash/1_team_project/notebooks/03_modeling/MyModel/ds_sub_fit/sub_fit_ho"
# Leaderboard on holdout data (DyStack):
#                            model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           CatBoost_BAG_L1_FULL       0.593076   0.589446    accuracy        0.015964            NaN   5.599576                 0.015964                     NaN           5.599576            1       True          8
# 1       WeightedEnsemble_L2_FULL       0.593076   0.589446    accuracy        0.019932            NaN   6.442231                 0.003968                     NaN           0.842655            2       True         12
# 2    NeuralNetFastAI_BAG_L2_FULL       0.586762   0.595188    accuracy        2.672576            NaN  38.753095                 0.056245                     NaN          14.470713            2       True         13
# 3            XGBoost_BAG_L1_FULL       0.585674   0.584846    accuracy        0.061567            NaN   1.151324                 0.061567                     NaN           1.151324            1       True         11
# 4         LightGBMXT_BAG_L1_FULL       0.580884   0.581798    accuracy        0.023222            NaN   0.754096                 0.023222                     NaN           0.754096            1       True          4
# 5         LightGBMXT_BAG_L2_FULL       0.577400   0.698038    accuracy        3.203476            NaN  55.877519                 0.587144                     NaN          31.595137            2       True         14
# 6       WeightedEnsemble_L3_FULL       0.577400   0.698038    accuracy        3.204426            NaN  56.825294                 0.000950                     NaN           0.947775            3       True         15
# 7           LightGBM_BAG_L1_FULL       0.572175   0.579512    accuracy        0.011296            NaN   0.374348                 0.011296                     NaN           0.374348            1       True          5
# 8    NeuralNetFastAI_BAG_L1_FULL       0.564772   0.577280    accuracy        0.058777            NaN   9.724492                 0.058777                     NaN           9.724492            1       True          3
# 9   RandomForestGini_BAG_L1_FULL       0.521010   0.516398    accuracy        0.537689       1.173862   2.057602                 0.537689                1.173862           2.057602            1       True          6
# 10  RandomForestEntr_BAG_L1_FULL       0.518833   0.516153    accuracy        0.379437       1.163446   1.791007                 0.379437                1.163446           1.791007            1       True          7
# 11    ExtraTreesGini_BAG_L1_FULL       0.516003   0.511553    accuracy        0.546201       0.995057   1.436100                 0.546201                0.995057           1.436100            1       True          9
# 12    ExtraTreesEntr_BAG_L1_FULL       0.514914   0.511526    accuracy        0.418063       1.038536   1.329834                 0.418063                1.038536           1.329834            1       True         10
# 13    KNeighborsUnif_BAG_L1_FULL       0.239495   0.243121    accuracy        0.397774       1.002699   0.030730                 0.397774                1.002699           0.030730            1       True          1
# 14    KNeighborsDist_BAG_L1_FULL       0.235794   0.239774    accuracy        0.166342       0.964700   0.033274                 0.166342                0.964700           0.033274            1       True          2
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	309s	 = DyStack   runtime |	591s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 591s
# AutoGluon will save models to "/Users/leehyunseung/Library/Mobile Documents/.Trash/1_team_project/notebooks/03_modeling/MyModel"
# Train Data Rows:    41336
# Train Data Columns: 5
# Label Column:       위험도
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 5
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    3270.61 MB
# 	Train Data (Original)  Memory Usage: 22.79 MB (0.7% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['시군구']
# 			CountVectorizer fit with vocabulary size = 104
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])        : 1 | ['시군구_평균사고']
# 		('object', [])       : 3 | ['사고유형', '도로형태', '사고도로조합']
# 		('object', ['text']) : 1 | ['시군구']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])                    :  3 | ['사고유형', '도로형태', '사고도로조합']
# 		('category', ['text_as_category'])  :  1 | ['시군구']
# 		('float', [])                       :  1 | ['시군구_평균사고']
# 		('int', ['binned', 'text_special']) :  4 | ['시군구.char_count', '시군구.word_count', '시군구.digit_ratio', '시군구.symbol_ratio. ']
# 		('int', ['text_ngram'])             : 73 | ['__nlp__.강릉시', '__nlp__.강원도', '__nlp__.강원특별자치도', '__nlp__.경기도', '__nlp__.경기도 고양시', ...]
# 	3.1s = Fit runtime
# 	5 features in original data used to generate 82 features in processed data.
# 	Train Data (Processed) Memory Usage: 6.43 MB (0.2% of available memory)
# Data preprocessing and feature engineering runtime = 3.18s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 110 L1 models, fit_strategy="sequential" ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 587.43s of the 587.40s of remaining time.
# 	0.243	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	1.25s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 585.89s of the 585.86s of remaining time.
# 	0.2401	 = Validation score   (accuracy)
# 	0.04s	 = Training   runtime
# 	1.33s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 584.46s of the 584.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.26%)
# 	0.5763	 = Validation score   (accuracy)
# 	25.36s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 557.05s of the 557.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.56%)
# 	0.5832	 = Validation score   (accuracy)
# 	2.73s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 552.01s of the 551.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.01%)
# 	0.5792	 = Validation score   (accuracy)
# 	2.9s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 547.60s of the 547.57s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 197 due to low memory. Expected memory usage reduced from 22.75% -> 15.0% of available memory...
# 	0.5177	 = Validation score   (accuracy)
# 	1.99s	 = Training   runtime
# 	1.15s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 543.57s of the 543.54s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 224 due to low memory. Expected memory usage reduced from 20.03% -> 15.0% of available memory...
# 	0.5187	 = Validation score   (accuracy)
# 	2.17s	 = Training   runtime
# 	1.29s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 539.11s of the 539.08s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 14.61% memory usage per fold, 58.45%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=14.61%)
# 	0.598	 = Validation score   (accuracy)
# 	215.52s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 321.56s of the 321.53s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 191 due to low memory. Expected memory usage reduced from 23.45% -> 15.0% of available memory...
# 	0.5139	 = Validation score   (accuracy)
# 	1.91s	 = Training   runtime
# 	1.19s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 317.30s of the 317.27s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 181 due to low memory. Expected memory usage reduced from 24.78% -> 15.0% of available memory...
# 	0.5135	 = Validation score   (accuracy)
# 	2.11s	 = Training   runtime
# 	1.16s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 313.41s of the 313.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.59%)
# 	0.5847	 = Validation score   (accuracy)
# 	6.55s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 303.87s of the 303.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.15%)
# 	Warning: Exception caused NeuralNetTorch_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=17486, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2169, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2055, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 390, in _fit
#     self._fit_folds(
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 848, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 631, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 587, in _process_fold_results
#     raise processed_exception
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 550, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=17486, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 300.04s of the 300.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=5.67%)
# 	0.5754	 = Validation score   (accuracy)
# 	3.28s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 294.75s of the 294.72s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 15.19% memory usage per fold, 60.74%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=15.19%)
# 2025-06-05 16:06:18,489	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=17460, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 16:06:18,494	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=17492, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 16:06:18,495	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=17485, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 16:06:18,498	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=17491, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 16:06:18,500	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=17490, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 16:06:18,502	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=17493, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 16:06:18,503	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.5977	 = Validation score   (accuracy)
# 	63.59s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 229.37s of the 229.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.97%)
# 	Warning: Exception caused NeuralNetTorch_r79_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=17662, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2169, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2055, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 390, in _fit
#     self._fit_folds(
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 848, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 631, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 587, in _process_fold_results
#     raise processed_exception
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 550, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=17662, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 226.37s of the 226.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.36%)
# 2025-06-05 16:07:31,741	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=17667, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 16:07:31,741	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-06-05 16:07:31,742	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=17670, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 16:07:31,743	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-06-05 16:07:31,744	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-06-05 16:07:31,745	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=17664, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 16:07:31,746	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.5804	 = Validation score   (accuracy)
# 	4.82s	 = Training   runtime
# 	1.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 219.79s of the 219.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.73%)
# 	0.5756	 = Validation score   (accuracy)
# 	95.56s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 121.34s of the 121.31s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 15.78% memory usage per fold, 63.12%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=15.78%)
# 	0.5928	 = Validation score   (accuracy)
# 	98.24s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 21.02s of the 21.00s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.65%)
# 	0.5823	 = Validation score   (accuracy)
# 	7.89s	 = Training   runtime
# 	2.81s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 10.49s of the 10.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.13%)
# 	Warning: Exception caused NeuralNetTorch_r22_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=18069, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2169, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2055, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 390, in _fit
#     self._fit_folds(
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 848, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 631, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 587, in _process_fold_results
#     raise processed_exception
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 550, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=18069, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 7.29s of the 7.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=7.77%)
# 2025-06-05 16:11:11,369	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-06-05 16:11:11,370	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=18102, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 16:11:11,370	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-06-05 16:11:11,371	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-06-05 16:11:11,373	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-06-05 16:11:11,374	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-06-05 16:11:11,374	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	0.5844	 = Validation score   (accuracy)
# 	6.09s	 = Training   runtime
# 	1.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the -0.54s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 1.0}
# 	0.598	 = Validation score   (accuracy)
# 	1.3s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 592.52s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 17029.9 rows/s (5167 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting model: KNeighborsUnif_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.04s	 = Training   runtime
# 	1.25s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.04s	 = Training   runtime
# 	1.33s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 18.
# 	11.19s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	1.07s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	0.5s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.99s	 = Training   runtime
# 	1.15s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	2.17s	 = Training   runtime
# 	1.29s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	21.99s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.91s	 = Training   runtime
# 	1.19s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	2.11s	 = Training   runtime
# 	1.16s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	0.87s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	1.66s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_BAG_L1_FULL ...
# 	8.45s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r131_BAG_L1_FULL ...
# 	1.91s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_r191_BAG_L1_FULL ...
# No improvement since epoch 0: early stopping
# 	26.28s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r9_BAG_L1_FULL ...
# 	10.77s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_r96_BAG_L1_FULL ...
# 	2.86s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_r33_BAG_L1_FULL ...
# 	0.78s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'CatBoost_BAG_L1': 1.0}
# 	1.3s	 = Training   runtime
# Updated best model to "CatBoost_BAG_L1_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "CatBoost_BAG_L1_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 92.81s ... Best model: "CatBoost_BAG_L1_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/leehyunseung/Library/Mobile Documents/.Trash/1_team_project/notebooks/03_modeling/MyModel")
# {'accuracy': 0.595355587808418,
#  'balanced_accuracy': 0.5860691577804529,
#  'mcc': 0.49793465678837673}

# %%
# 성능 확인
leaderboard = predictor.leaderboard(silent=True)
print(leaderboard)
# Out:
#                                model  score_val eval_metric  pred_time_val  \
# 0                    CatBoost_BAG_L1   0.598026    accuracy       0.303087
# 1                WeightedEnsemble_L2   0.598026    accuracy       0.305641
# 2               CatBoost_r177_BAG_L1   0.597711    accuracy       0.214653
# 3                 CatBoost_r9_BAG_L1   0.592825    accuracy       0.219187
# 4                     XGBoost_BAG_L1   0.584720    accuracy       0.878725
# 5                 XGBoost_r33_BAG_L1   0.584382    accuracy       1.015754
# 6                  LightGBMXT_BAG_L1   0.583245    accuracy       0.649648
# 7                LightGBM_r96_BAG_L1   0.582277    accuracy       2.813833
# 8               LightGBM_r131_BAG_L1   0.580390    accuracy       1.032578
# 9                    LightGBM_BAG_L1   0.579229    accuracy       0.225829
# 10            NeuralNetFastAI_BAG_L1   0.576350    accuracy       0.349786
# 11       NeuralNetFastAI_r191_BAG_L1   0.575576    accuracy       0.542024
# 12              LightGBMLarge_BAG_L1   0.575358    accuracy       0.395559
# 13           RandomForestEntr_BAG_L1   0.518676    accuracy       1.291203
# 14           RandomForestGini_BAG_L1   0.517684    accuracy       1.148617
# 15             ExtraTreesGini_BAG_L1   0.513910    accuracy       1.187906
# 16             ExtraTreesEntr_BAG_L1   0.513451    accuracy       1.158427
# 17             KNeighborsUnif_BAG_L1   0.242960    accuracy       1.245349
# 18             KNeighborsDist_BAG_L1   0.240105    accuracy       1.326618
# 19      RandomForestGini_BAG_L1_FULL        NaN    accuracy       1.148617
# 20        ExtraTreesEntr_BAG_L1_FULL        NaN    accuracy       1.158427
# 21        ExtraTreesGini_BAG_L1_FULL        NaN    accuracy       1.187906
# 22        KNeighborsUnif_BAG_L1_FULL        NaN    accuracy       1.245349
# 23      RandomForestEntr_BAG_L1_FULL        NaN    accuracy       1.291203
# 24        KNeighborsDist_BAG_L1_FULL        NaN    accuracy       1.326618
# 25           XGBoost_r33_BAG_L1_FULL        NaN    accuracy            NaN
# 26               XGBoost_BAG_L1_FULL        NaN    accuracy            NaN
# 27          WeightedEnsemble_L2_FULL        NaN    accuracy            NaN
# 28  NeuralNetFastAI_r191_BAG_L1_FULL        NaN    accuracy            NaN
# 29       NeuralNetFastAI_BAG_L1_FULL        NaN    accuracy            NaN
# 30          LightGBM_r96_BAG_L1_FULL        NaN    accuracy            NaN
# 31         LightGBM_r131_BAG_L1_FULL        NaN    accuracy            NaN
# 32              LightGBM_BAG_L1_FULL        NaN    accuracy            NaN
# 33            LightGBMXT_BAG_L1_FULL        NaN    accuracy            NaN
# 34         LightGBMLarge_BAG_L1_FULL        NaN    accuracy            NaN
# 35           CatBoost_r9_BAG_L1_FULL        NaN    accuracy            NaN
# 36         CatBoost_r177_BAG_L1_FULL        NaN    accuracy            NaN
# 37              CatBoost_BAG_L1_FULL        NaN    accuracy            NaN
#
#       fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   215.518219                0.303087         215.518219            1
# 1   216.813530                0.002554           1.295311            2
# 2    63.592906                0.214653          63.592906            1
# 3    98.242763                0.219187          98.242763            1
# 4     6.546934                0.878725           6.546934            1
# 5     6.089775                1.015754           6.089775            1
# 6     2.729580                0.649648           2.729580            1
# 7     7.894179                2.813833           7.894179            1
# 8     4.824117                1.032578           4.824117            1
# 9     2.901264                0.225829           2.901264            1
# 10   25.361705                0.349786          25.361705            1
# 11   95.556393                0.542024          95.556393            1
# 12    3.275802                0.395559           3.275802            1
# 13    2.174652                1.291203           2.174652            1
# 14    1.987070                1.148617           1.987070            1
# 15    1.908605                1.187906           1.908605            1
# 16    2.112711                1.158427           2.112711            1
# 17    0.035228                1.245349           0.035228            1
# 18    0.038034                1.326618           0.038034            1
# 19    1.987070                1.148617           1.987070            1
# 20    2.112711                1.158427           2.112711            1
# 21    1.908605                1.187906           1.908605            1
# 22    0.035228                1.245349           0.035228            1
# 23    2.174652                1.291203           2.174652            1
# 24    0.038034                1.326618           0.038034            1
# 25    0.775464                     NaN           0.775464            1
# 26    0.873532                     NaN           0.873532            1
# 27   23.282613                     NaN           1.295311            2
# 28   26.276021                     NaN          26.276021            1
# 29   11.187297                     NaN          11.187297            1
# 30    2.859347                     NaN           2.859347            1
# 31    1.905574                     NaN           1.905574            1
# 32    0.498236                     NaN           0.498236            1
# 33    1.066311                     NaN           1.066311            1
# 34    1.661271                     NaN           1.661271            1
# 35   10.768777                     NaN          10.768777            1
# 36    8.452499                     NaN           8.452499            1
# 37   21.987302                     NaN          21.987302            1
#
#     can_infer  fit_order
# 0       False          8
# 1       False         19
# 2       False         13
# 3       False         16
# 4       False         11
# 5       False         18
# 6       False          4
# 7       False         17
# 8       False         14
# 9       False          5
# 10      False          3
# 11      False         15
# 12      False         12
# 13       True          7
# 14       True          6
# 15       True          9
# 16       True         10
# 17       True          1
# 18       True          2
# 19       True         25
# 20       True         29
# 21       True         28
# 22       True         20
# 23       True         26
# 24       True         21
# 25       True         37
# 26       True         30
# 27       True         38
# 28       True         34
# 29       True         22
# 30       True         36
# 31       True         33
# 32       True         24
# 33       True         23
# 34       True         31
# 35       True         35
# 36       True         32
# 37       True         27

# %%
# 예측용 샘플 생성
sample = pd.DataFrame([{
    '시군구': '종로구',
    '사고유형': '차대사람 - 차도통행중',
    '도로형태': '교차로 - 교차로부근'
}])

# 누락된 feature 추가
sample['시군구_평균사고'] = sample['시군구'].map(avg_by_area)
sample['사고도로조합'] = sample['사고유형'] + '_' + sample['도로형태']

# 예측
pred = predictor.predict(sample)
pred
# Out:
# 0    2
# Name: 위험도, dtype: object

# %%
# df = pd.read_csv('../../data/preprocessed_data/시도_시군구별_보행자_사고_사고유형_전처리ver.csv')

# # 피해 가중 점수 계산
# df['피해가중점수'] = (
#     df['사망자수'] * 1 +
#     df['중상자수'] * 0.1 +
#     df['경상자수'] * 0.01 +
#     df['부상신고자수'] * 0.001
# )

# # 사고유형 가중치
# type_weight = df.groupby('사고유형')['피해가중점수'].mean()
# df['사고유형가중치'] = df['사고유형'].map(type_weight)

# # 도로형태 가중치
# road_weight = df.groupby('도로형태')['피해가중점수'].mean()
# df['도로형태가중치'] = df['도로형태'].map(road_weight)

# # 최종 위험 점수
# df['최종위험점수'] = df['피해가중점수'] + 0.5 * (df['사고유형가중치'] + df['도로형태가중치'])

# # 위험도 등급 (1=안전, 5=위험)
# df['위험도'] = pd.qcut(df['최종위험점수'], q=5, labels=[1, 2, 3, 4, 5]).astype(str)

# # 시군구별 평균 피해가중점수
# area_avg = df.groupby('시군구')['피해가중점수'].mean().to_dict()
# df['시군구_평균사고'] = df['시군구'].map(area_avg)

# # 전체 평균과의 편차
# overall_avg = df['피해가중점수'].mean()
# df['시군구_편차'] = df['시군구_평균사고'] - overall_avg

# # 조합 변수 생성
# df['사고도로조합'] = df['사고유형'] + '_' + df['도로형태']
# df['시군구_사고유형'] = df['시군구'] + '_' + df['사고유형']
# df['시군구_도로형태'] = df['시군구'] + '_' + df['도로형태']
# HTML(df.head(5).to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>연도</th>
#       <th>시군구</th>
#       <th>법정동코드</th>
#       <th>사고내용</th>
#       <th>사망자수</th>
#       <th>중상자수</th>
#       <th>경상자수</th>
#       <th>부상신고자수</th>
#       <th>사고유형</th>
#       <th>도로형태</th>
#       <th>피해자 상해정도</th>
#       <th>피해가중점수</th>
#       <th>사고유형가중치</th>
#       <th>도로형태가중치</th>
#       <th>최종위험점수</th>
#       <th>위험도</th>
#       <th>시군구_평균사고</th>
#       <th>시군구_편차</th>
#       <th>사고도로조합</th>
#       <th>시군구_사고유형</th>
#       <th>시군구_도로형태</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2020</td>
#       <td>서울특별시 종로구 창성동</td>
#       <td>1111010500</td>
#       <td>중상사고</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>차대사람 - 차도통행중</td>
#       <td>교차로 - 교차로부근</td>
#       <td>중상</td>
#       <td>0.10</td>
#       <td>0.131882</td>
#       <td>0.111938</td>
#       <td>0.221910</td>
#       <td>4</td>
#       <td>0.10</td>
#       <td>-0.015843</td>
#       <td>차대사람 - 차도통행중_교차로 - 교차로부근</td>
#       <td>서울특별시 종로구 창성동_차대사람 - 차도통행중</td>
#       <td>서울특별시 종로구 창성동_교차로 - 교차로부근</td>
#     </tr>
#     <tr>
#       <td>2020</td>
#       <td>서울특별시 종로구 창성동</td>
#       <td>1111010500</td>
#       <td>중상사고</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>차대사람 - 차도통행중</td>
#       <td>교차로 - 교차로안</td>
#       <td>중상</td>
#       <td>0.10</td>
#       <td>0.131882</td>
#       <td>0.117951</td>
#       <td>0.224917</td>
#       <td>4</td>
#       <td>0.10</td>
#       <td>-0.015843</td>
#       <td>차대사람 - 차도통행중_교차로 - 교차로안</td>
#       <td>서울특별시 종로구 창성동_차대사람 - 차도통행중</td>
#       <td>서울특별시 종로구 창성동_교차로 - 교차로안</td>
#     </tr>
#     <tr>
#       <td>2020</td>
#       <td>서울특별시 종로구 통인동</td>
#       <td>1111010800</td>
#       <td>경상사고</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>차대사람 - 기타</td>
#       <td>단일로 - 기타</td>
#       <td>경상</td>
#       <td>0.01</td>
#       <td>0.092425</td>
#       <td>0.121204</td>
#       <td>0.116814</td>
#       <td>1</td>
#       <td>0.01</td>
#       <td>-0.105843</td>
#       <td>차대사람 - 기타_단일로 - 기타</td>
#       <td>서울특별시 종로구 통인동_차대사람 - 기타</td>
#       <td>서울특별시 종로구 통인동_단일로 - 기타</td>
#     </tr>
#     <tr>
#       <td>2020</td>
#       <td>서울특별시 종로구 누상동</td>
#       <td>1111010900</td>
#       <td>경상사고</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>차대사람 - 차도통행중</td>
#       <td>교차로 - 교차로안</td>
#       <td>경상</td>
#       <td>0.01</td>
#       <td>0.131882</td>
#       <td>0.117951</td>
#       <td>0.134917</td>
#       <td>2</td>
#       <td>0.01</td>
#       <td>-0.105843</td>
#       <td>차대사람 - 차도통행중_교차로 - 교차로안</td>
#       <td>서울특별시 종로구 누상동_차대사람 - 차도통행중</td>
#       <td>서울특별시 종로구 누상동_교차로 - 교차로안</td>
#     </tr>
#     <tr>
#       <td>2020</td>
#       <td>서울특별시 종로구 누상동</td>
#       <td>1111010900</td>
#       <td>경상사고</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>차대사람 - 기타</td>
#       <td>단일로 - 기타</td>
#       <td>경상</td>
#       <td>0.01</td>
#       <td>0.092425</td>
#       <td>0.121204</td>
#       <td>0.116814</td>
#       <td>1</td>
#       <td>0.01</td>
#       <td>-0.105843</td>
#       <td>차대사람 - 기타_단일로 - 기타</td>
#       <td>서울특별시 종로구 누상동_차대사람 - 기타</td>
#       <td>서울특별시 종로구 누상동_단일로 - 기타</td>
#     </tr>
#   </tbody>
# </table>

# %%
# # Feature 목록
# feature_cols = [
#     '시군구', '사고유형', '도로형태',
#     '시군구_평균사고', '시군구_편차',
#     '사고도로조합', '시군구_사고유형', '시군구_도로형태'
# ]
# target_col = '위험도'

# # 결측치 제거
# df_model = df[feature_cols + [target_col]].dropna()

# # 학습/테스트 분리
# train_data, test_data = train_test_split(
#     df_model, test_size=0.2, random_state=42, stratify=df_model[target_col]
# )

# # AutoGluon 학습
# predictor = TabularPredictor(label=target_col, path='MyModel_2', problem_type='multiclass').fit(
#     train_data=train_data,
#     presets='high_quality',  # 성능 우선
#     time_limit=900,          # 15분 제한
#     num_cpus=10,
#     verbosity=2
# )

# # 평가
# predictor.evaluate(test_data)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.3.1
# Python Version:     3.11.11
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 24.4.0: Fri Apr 11 18:33:39 PDT 2025; root:xnu-11417.101.15~117/RELEASE_ARM64_T6020
# CPU Count:          12
# Memory Avail:       2.66 GB / 16.00 GB (16.6%)
# Disk Space Avail:   6.31 GB / 460.43 GB (1.4%)
# 	WARNING: Available disk space is low and there is a risk that AutoGluon will run out of disk during fit, causing an exception.
# 	We recommend a minimum available disk space of 10 GB, and large datasets may require more.
# ===================================================
# Presets specified: ['high_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 225s of the 900s of remaining time (25%).
# 		Context path: "/Users/leehyunseung/Documents/GitHub/1_team_project/notebooks/03_modeling/MyModel_2/ds_sub_fit/sub_fit_ho"
# Leaderboard on holdout data (DyStack):
#                            model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0    NeuralNetFastAI_BAG_L2_FULL       0.581537   0.585717    accuracy        3.270630            NaN  48.946758                 0.053702                     NaN          12.811347            2       True         10
# 1         LightGBMXT_BAG_L1_FULL       0.580666   0.584737    accuracy        0.027654            NaN   1.135443                 0.027654                     NaN           1.135443            1       True          4
# 2       WeightedEnsemble_L2_FULL       0.580449   0.585200    accuracy        0.127542            NaN  16.192374                 0.001852                     NaN           0.479969            2       True          9
# 3           LightGBM_BAG_L1_FULL       0.579795   0.579457    accuracy        0.016094            NaN   0.596526                 0.016094                     NaN           0.596526            1       True          5
# 4           CatBoost_BAG_L1_FULL       0.578924   0.581390    accuracy        0.032693            NaN   2.840474                 0.032693                     NaN           2.840474            1       True          8
# 5    NeuralNetFastAI_BAG_L1_FULL       0.564990   0.577334    accuracy        0.049249            NaN  11.139962                 0.049249                     NaN          11.139962            1       True          3
# 6         LightGBMXT_BAG_L2_FULL       0.564555   0.644721    accuracy        3.397992            NaN  46.076943                 0.181064                     NaN           9.941532            2       True         11
# 7       WeightedEnsemble_L3_FULL       0.564555   0.644721    accuracy        3.399305            NaN  46.709717                 0.001313                     NaN           0.632774            3       True         12
# 8   RandomForestGini_BAG_L1_FULL       0.521881   0.522685    accuracy        0.667440       3.518639  10.200136                 0.667440                3.518639          10.200136            1       True          6
# 9   RandomForestEntr_BAG_L1_FULL       0.521446   0.521650    accuracy        0.548326       3.348929   9.805260                 0.548326                3.348929           9.805260            1       True          7
# 10    KNeighborsUnif_BAG_L1_FULL       0.486392   0.483793    accuracy        1.005545       5.457640   0.231449                 1.005545                5.457640           0.231449            1       True          1
# 11    KNeighborsDist_BAG_L1_FULL       0.482909   0.486569    accuracy        0.869927       5.157056   0.186161                 0.869927                5.157056           0.186161            1       True          2
# 	0	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: True)
# 	281s	 = DyStack   runtime |	619s	 = Remaining runtime
# Starting main fit with num_stack_levels=0.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=0)`
# Beginning AutoGluon training ... Time limit = 619s
# AutoGluon will save models to "/Users/leehyunseung/Documents/GitHub/1_team_project/notebooks/03_modeling/MyModel_2"
# Train Data Rows:    41336
# Train Data Columns: 8
# Label Column:       위험도
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 5
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    3385.98 MB
# 	Train Data (Original)  Memory Usage: 38.08 MB (1.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['시군구', '시군구_사고유형', '시군구_도로형태']
# 			CountVectorizer fit with vocabulary size = 869
# 		Warning: Due to memory constraints, ngram feature count is being reduced. Allocate more memory to maximize model quality.
# 		Reducing Vectorizer vocab size from 869 to 866 to avoid OOM error
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])        : 2 | ['시군구_평균사고', '시군구_편차']
# 		('object', [])       : 3 | ['사고유형', '도로형태', '사고도로조합']
# 		('object', ['text']) : 3 | ['시군구', '시군구_사고유형', '시군구_도로형태']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])                    :   3 | ['사고유형', '도로형태', '사고도로조합']
# 		('category', ['text_as_category'])  :   3 | ['시군구', '시군구_사고유형', '시군구_도로형태']
# 		('float', [])                       :   2 | ['시군구_평균사고', '시군구_편차']
# 		('int', ['binned', 'text_special']) :  14 | ['시군구.char_count', '시군구.word_count', '시군구.digit_ratio', '시군구.symbol_ratio. ', '시군구_사고유형.char_count', ...]
# 		('int', ['text_ngram'])             : 621 | ['__nlp__.가평군', '__nlp__.강남구', '__nlp__.강동구', '__nlp__.강릉시', '__nlp__.강북구', ...]
# 	6.7s = Fit runtime
# 	8 features in original data used to generate 643 features in processed data.
# 	Train Data (Processed) Memory Usage: 50.50 MB (1.4% of available memory)
# Data preprocessing and feature engineering runtime = 6.85s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 110 L1 models, fit_strategy="sequential" ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 612.12s of the 612.11s of remaining time.
# 	0.4873	 = Validation score   (accuracy)
# 	0.28s	 = Training   runtime
# 	8.19s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 602.74s of the 602.74s of remaining time.
# 	0.4852	 = Validation score   (accuracy)
# 	0.27s	 = Training   runtime
# 	8.23s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 593.96s of the 593.95s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.64% memory usage per fold, 66.56%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=16.64%)
# 	0.5768	 = Validation score   (accuracy)
# 	38.56s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 551.94s of the 551.93s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 15.60% memory usage per fold, 62.39%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=15.60%)
# 	0.583	 = Validation score   (accuracy)
# 	10.46s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 538.79s of the 538.79s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 14.81% memory usage per fold, 59.26%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=14.81%)
# 	0.5778	 = Validation score   (accuracy)
# 	10.1s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 526.62s of the 526.61s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 221 due to low memory. Expected memory usage reduced from 20.33% -> 15.0% of available memory...
# 	0.5232	 = Validation score   (accuracy)
# 	12.91s	 = Training   runtime
# 	4.2s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 508.75s of the 508.74s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 200 due to low memory. Expected memory usage reduced from 22.47% -> 15.0% of available memory...
# 	0.5231	 = Validation score   (accuracy)
# 	11.78s	 = Training   runtime
# 	3.87s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 492.03s of the 492.03s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 1 folds in parallel instead (Estimated 45.14% memory usage per fold, 45.14%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=45.14%)
# 		Switching to pseudo sequential ParallelFoldFittingStrategy to avoid Python memory leakage.
# 		Overrule this behavior by setting fold_fitting_strategy to 'sequential_local' in ag_args_ensemble when when calling `predictor.fit`
# 	0.5984	 = Validation score   (accuracy)
# 	254.07s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 235.01s of the 235.00s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 150 due to low memory. Expected memory usage reduced from 29.85% -> 15.0% of available memory...
# 	0.5159	 = Validation score   (accuracy)
# 	8.75s	 = Training   runtime
# 	3.26s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 222.01s of the 222.00s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 162 due to low memory. Expected memory usage reduced from 27.77% -> 15.0% of available memory...
# 	0.5149	 = Validation score   (accuracy)
# 	10.37s	 = Training   runtime
# 	3.35s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 207.11s of the 207.10s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 26.60% memory usage per fold, 53.21%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=5, gpus=0, memory=26.60%)
# 	0.5855	 = Validation score   (accuracy)
# 	25.28s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 178.87s of the 178.87s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 10.23% memory usage per fold, 40.94%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=10.23%)
# 	Warning: Exception caused NeuralNetTorch_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=4761, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2169, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2055, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 390, in _fit
#     self._fit_folds(
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 848, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 631, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 587, in _process_fold_results
#     raise processed_exception
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 550, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=4761, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 174.54s of the 174.53s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 35.02% memory usage per fold, 70.03%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=5, gpus=0, memory=35.02%)
# 2025-06-05 14:34:11,785	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=4756, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 14:34:11,792	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=4762, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 14:34:11,792	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=4758, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 14:34:11,793	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=4759, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 14:34:11,794	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=4760, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 	0.5762	 = Validation score   (accuracy)
# 	59.45s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 113.30s of the 113.30s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 1 folds in parallel instead (Estimated 43.64% memory usage per fold, 43.64%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=10, gpus=0, memory=43.64%)
# 		Switching to pseudo sequential ParallelFoldFittingStrategy to avoid Python memory leakage.
# 		Overrule this behavior by setting fold_fitting_strategy to 'sequential_local' in ag_args_ensemble when when calling `predictor.fit`
# 	0.5961	 = Validation score   (accuracy)
# 	104.02s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 6.85s of the 6.85s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 11.52% memory usage per fold, 46.07%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=2, gpus=0, memory=11.52%)
# 	Warning: Exception caused NeuralNetTorch_r79_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=5120, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2169, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/trainer/abstract_trainer.py", line 2055, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 390, in _fit
#     self._fit_folds(
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 848, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 631, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 587, in _process_fold_results
#     raise processed_exception
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 550, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/worker.py", line 2782, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/ray/_private/worker.py", line 929, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=5120, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 2.15s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 1.0}
# 	0.5984	 = Validation score   (accuracy)
# 	1.04s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 617.91s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 18130.3 rows/s (5167 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting model: KNeighborsUnif_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.28s	 = Training   runtime
# 	8.19s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.27s	 = Training   runtime
# 	8.23s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 2025-06-05 14:37:04,078	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=5118, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 14:37:04,080	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=5117, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 14:37:04,081	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-06-05 14:37:04,082	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=5122, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 2025-06-05 14:37:04,083	ERROR worker.py:420 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=5119, ip=127.0.0.1)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/core/models/abstract/abstract_model.py", line 1051, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 209, in _fit
#     train_dataset = self._generate_dataset(X=X, y=y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 687, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/torch/tabular_nn_torch.py", line 749, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/ESTsoft_TP_1/lib/python3.11/site-packages/autogluon/tabular/models/tabular_nn/utils/data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# 	Stopping at the best epoch learned earlier - 15.
# 	10.19s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	1.79s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	0.88s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	12.91s	 = Training   runtime
# 	4.2s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	11.78s	 = Training   runtime
# 	3.87s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	23.63s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	8.75s	 = Training   runtime
# 	3.26s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	10.37s	 = Training   runtime
# 	3.35s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	1.49s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	2.35s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_r177_BAG_L1_FULL ...
# 	9.57s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'CatBoost_BAG_L1': 1.0}
# 	1.04s	 = Training   runtime
# Updated best model to "CatBoost_BAG_L1_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "CatBoost_BAG_L1_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 62.65s ... Best model: "CatBoost_BAG_L1_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/leehyunseung/Documents/GitHub/1_team_project/notebooks/03_modeling/MyModel_2")
# {'accuracy': 0.5929366231253024,
#  'balanced_accuracy': 0.5834618133963303,
#  'mcc': 0.494717728607096}

# %%
# leaderboard = predictor.leaderboard(silent=True)
# print(leaderboard)
# Out:
#                            model  score_val eval_metric  pred_time_val  \
# 0                CatBoost_BAG_L1   0.598389    accuracy       0.284616
# 1            WeightedEnsemble_L2   0.598389    accuracy       0.287621
# 2           CatBoost_r177_BAG_L1   0.596139    accuracy       0.239805
# 3                 XGBoost_BAG_L1   0.585519    accuracy       0.467451
# 4              LightGBMXT_BAG_L1   0.583027    accuracy       0.447050
# 5                LightGBM_BAG_L1   0.577753    accuracy       0.204574
# 6         NeuralNetFastAI_BAG_L1   0.576785    accuracy       0.340838
# 7           LightGBMLarge_BAG_L1   0.576229    accuracy       0.226127
# 8        RandomForestGini_BAG_L1   0.523176    accuracy       4.196429
# 9        RandomForestEntr_BAG_L1   0.523055    accuracy       3.873621
# 10         ExtraTreesGini_BAG_L1   0.515943    accuracy       3.264198
# 11         ExtraTreesEntr_BAG_L1   0.514926    accuracy       3.352923
# 12         KNeighborsUnif_BAG_L1   0.487251    accuracy       8.192992
# 13         KNeighborsDist_BAG_L1   0.485219    accuracy       8.228383
# 14    ExtraTreesGini_BAG_L1_FULL        NaN    accuracy       3.264198
# 15    ExtraTreesEntr_BAG_L1_FULL        NaN    accuracy       3.352923
# 16  RandomForestEntr_BAG_L1_FULL        NaN    accuracy       3.873621
# 17  RandomForestGini_BAG_L1_FULL        NaN    accuracy       4.196429
# 18    KNeighborsUnif_BAG_L1_FULL        NaN    accuracy       8.192992
# 19    KNeighborsDist_BAG_L1_FULL        NaN    accuracy       8.228383
# 20           XGBoost_BAG_L1_FULL        NaN    accuracy            NaN
# 21      WeightedEnsemble_L2_FULL        NaN    accuracy            NaN
# 22   NeuralNetFastAI_BAG_L1_FULL        NaN    accuracy            NaN
# 23          LightGBM_BAG_L1_FULL        NaN    accuracy            NaN
# 24        LightGBMXT_BAG_L1_FULL        NaN    accuracy            NaN
# 25     LightGBMLarge_BAG_L1_FULL        NaN    accuracy            NaN
# 26     CatBoost_r177_BAG_L1_FULL        NaN    accuracy            NaN
# 27          CatBoost_BAG_L1_FULL        NaN    accuracy            NaN
#
#       fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   254.065232                0.284616         254.065232            1
# 1   255.100407                0.003005           1.035175            2
# 2   104.024173                0.239805         104.024173            1
# 3    25.275271                0.467451          25.275271            1
# 4    10.464253                0.447050          10.464253            1
# 5    10.098763                0.204574          10.098763            1
# 6    38.557274                0.340838          38.557274            1
# 7    59.452343                0.226127          59.452343            1
# 8    12.905424                4.196429          12.905424            1
# 9    11.776987                3.873621          11.776987            1
# 10    8.745685                3.264198           8.745685            1
# 11   10.366866                3.352923          10.366866            1
# 12    0.281250                8.192992           0.281250            1
# 13    0.266390                8.228383           0.266390            1
# 14    8.745685                3.264198           8.745685            1
# 15   10.366866                3.352923          10.366866            1
# 16   11.776987                3.873621          11.776987            1
# 17   12.905424                4.196429          12.905424            1
# 18    0.281250                8.192992           0.281250            1
# 19    0.266390                8.228383           0.266390            1
# 20    1.485896                     NaN           1.485896            1
# 21   24.662982                     NaN           1.035175            2
# 22   10.186864                     NaN          10.186864            1
# 23    0.875823                     NaN           0.875823            1
# 24    1.789201                     NaN           1.789201            1
# 25    2.345797                     NaN           2.345797            1
# 26    9.570397                     NaN           9.570397            1
# 27   23.627807                     NaN          23.627807            1
#
#     can_infer  fit_order
# 0       False          8
# 1       False         14
# 2       False         13
# 3       False         11
# 4       False          4
# 5       False          5
# 6       False          3
# 7       False         12
# 8        True          6
# 9        True          7
# 10       True          9
# 11       True         10
# 12       True          1
# 13       True          2
# 14       True         23
# 15       True         24
# 16       True         21
# 17       True         20
# 18       True         15
# 19       True         16
# 20       True         25
# 21       True         28
# 22       True         17
# 23       True         19
# 24       True         18
# 25       True         26
# 26       True         27
# 27       True         22

# %%
# 1차 결과 (위험점수 기반)
# 해석 가능성:       높음 (정량적 피해 반영)
# 지역 의존성:       낮음 (지역 독립적 사용 가능)
# 일반화 가능성:     높음 (새 지역에도 적용 가능)
# 모델 복잡도:       낮음 (수치형 중심)
# 성능:            소폭 우세

# 2차 결과 (조합 기반)
# 해석 가능성:       낮음 (복합조합 가중치 해석 어려움)
# 지역 의존성:       높음 (시군구 중심 특성)
# 일반화 가능성:      낮음 (훈련된 조합 정보 필요)
# 모델 복잡도:       높음 (카테고리 피처 다수)
# 성능:            근소 열세

# =======================================================

# 사용한 feature

# 피해가중점수 (사망자수, 중상자수, 경상자수, 부상신고자수 반영)
# 사고유형가중치
# 도로형태가중치
# =======================================================

# 최종위험점수 = 피해가중점수 + 0.5 × (사고유형가중치 + 도로형태가중치)

# =======================================================
# 예측 성능 지표

# Accuracy: 0.595
# Balanced Accuracy: 0.586
# MCC (Matthews Correlation Coefficient): 0.498

# =======================================================

# 모델 성능
# Top model: CatBoost_BAG_L1 + WeightedEnsemble_L2
# 최고 성능: Accuracy 0.598
